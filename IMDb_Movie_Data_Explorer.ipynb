# %% [markdown]
# <a href="https://colab.research.google.com/github/IshuaB-sudo/Python-Projects/blob/main/IMDb_Movie_Data_Explorer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("imdb.csv", low_memory=False)

# Show first 5 rows
print("🔹 Preview of dataset:")
print(df.head())

# Drop missing values in 'genre' and 'year'
df = df.dropna(subset=['genre', 'year'])

# Convert 'year' to int
df['year'] = df['year'].astype(int)

# Top 10 genres
print("\n🔹 Top Genres:")
top_genres = df['genre'].value_counts().head(10)
print(top_genres)

# Plot genre distribution
top_genres.plot(kind='bar', title='Top 10 Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()

# Movies released per year (2000–2020)
df_filtered = df[df['year'].between(2000, 2020)]
movies_per_year = df_filtered['year'].value_counts().sort_index()

# Plot movies by year
movies_per_year.plot(kind='line', marker='o', title='Movies Released Per Year (2000–2020)')
plt.xlabel('Year')
plt.ylabel('Number of Movies')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 🔹 Preview of dataset:
#    lister-item-index       lister-item-header certificate runtime  \
# 0                1.0          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black          18  59 min
# 3                4.0             Black Mirror          18  60 min
# 4                5.0              Money Heist          15  60 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 2      Comedy, Crime, Drama     8.0    319,342
# 3    Drama, Mystery, Sci-Fi     8.7    636,319
# 4      Action, Crime, Drama     8.2    529,086
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-8a70734ccc45> in <cell line: 0>()
#      10
# ...

# %%
print(df.columns)
# Out:
# Index(['lister-item-index', 'lister-item-header', 'certificate', 'runtime',
#        'genre', 'rating', 'votes'],
#       dtype='object')

# %%
# IMDb Movie Data Explorer
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("imdb.csv", low_memory=False)  # Change filename if different

# View column names
print("📌 Columns in dataset:")
print(df.columns)

# Preview first 5 rows
print("\n🔹 Preview of dataset:")
print(df.head())

# -----------------------------------------
# GENRE ANALYSIS
# -----------------------------------------
df = df.dropna(subset=['genre'])
top_genres = df['genre'].value_counts().head(10)

# Plot Top Genres
top_genres.plot(kind='bar', title='Top 10 Movie Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Movies')
plt.tight_layout()
plt.show()

# -----------------------------------------
# RATING ANALYSIS
# -----------------------------------------
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
df = df.dropna(subset=['rating'])

# Plot Rating Distribution
df['rating'].plot(kind='hist', bins=20, title='IMDb Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Number of Movies')
plt.grid(True)
plt.tight_layout()
plt.show()

# -----------------------------------------
# CERTIFICATE ANALYSIS
# -----------------------------------------
df = df.dropna(subset=['certificate'])
top_cert = df['certificate'].value_counts().head(10)

# Plot Certificates
top_cert.plot(kind='bar', title='Top Movie Certificates')
plt.xlabel('Certificate')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# -----------------------------------------
# MOST VOTED MOVIES
# -----------------------------------------
df['votes'] = pd.to_numeric(df['votes'], errors='coerce')
df = df.dropna(subset=['votes'])

top_voted = df.sort_values('votes', ascending=False).head(10)
print("\n🎥 Top 10 Most Voted Movies:")
print(top_voted[['lister-item-header', 'votes']])
# Out:
# 📌 Columns in dataset:
# Index(['lister-item-index', 'lister-item-header', 'certificate', 'runtime',
#        'genre', 'rating', 'votes'],
#       dtype='object')
#
# 🔹 Preview of dataset:
#    lister-item-index       lister-item-header certificate runtime  \
# 0                1.0          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black          18  59 min
# 3                4.0             Black Mirror          18  60 min
# 4                5.0              Money Heist          15  60 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  1,327,188
# 1  Drama, Mystery, Thriller     7.5    314,321
# 2      Comedy, Crime, Drama     8.0    319,342
# 3    Drama, Mystery, Sci-Fi     8.7    636,319
# 4      Action, Crime, Drama     8.2    529,086
# 🎥 Top 10 Most Voted Movies:
# Empty DataFrame
# Columns: [lister-item-header, votes]
# Index: []
